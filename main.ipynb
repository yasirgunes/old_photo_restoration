# %%
# include numpy, matplotlib, and opencv
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# import defaultdict
from collections import defaultdict

# %%
# open the image
img = cv.imread('photos/old/h.png', cv.IMREAD_COLOR)

cv.cvtColor(img, cv.COLOR_BGR2RGB, img)

# show the image
plt.imshow(img)
plt.show()

# %%
def calculate_CDF(img):
    # img is a 2D numpy array with RGB
    # calculate the histogram manually
    histogram = defaultdict(int)
